# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# import the requests library
import requests

# import the API key 
from config import weather_api_keys

# starting URL for weather map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    #create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather = city_weather['weather']
        city_desc = [sub['description'] for sub in weather]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | marang
# Processing Record 6 of Set 1 | mareeba
# Processing Record 7 of Set 1 | zvecka
# Processing Record 8 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | asino
# Processing Record 12 of Set 1 | moyale
# Processing Record 13 of Set 1 | calvinia
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | sobolevo
# Processing Record 16 of Set 1 | cuamba
# Processing Record 17 of Set 1 | broome
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | aleksandrov gay
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | cotonou
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | chodavaram
# Processing Record 30 of Set 1 | sioux lookout
# Processing Record 31 of Set 1 | tuatapere
# Processing Record 32 of Set 1 | mossendjo
# Processing Record 33 of Set 1 | san cristobal
# Processing Record 34 of Set 1 | tessalit
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | saint-augustin
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | harper
# Processing Record 40 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 41 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 1 | faanui
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | gallup
# Processing Record 46 of Set 1 | shache
# Processing Record 47 of Set 1 | ambon
# Processing Record 48 of Set 1 | dunedin
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | husavik
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | toora-khem
# Processing Record 4 of Set 2 | shakiso
# Processing Record 5 of Set 2 | pemangkat
# Processing Record 6 of Set 2 | dingle
# Processing Record 7 of Set 2 | andra
# Processing Record 8 of Set 2 | itaituba
# Processing Record 9 of Set 2 | korla
# Processing Record 10 of Set 2 | lompoc
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | richards bay
# Processing Record 14 of Set 2 | pevek
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | samana
# Processing Record 17 of Set 2 | tucumcari
# Processing Record 18 of Set 2 | cayenne
# Processing Record 19 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | tynda
# Processing Record 24 of Set 2 | bandarbeyla
# Processing Record 25 of Set 2 | barra
# Processing Record 26 of Set 2 | teguldet
# Processing Record 27 of Set 2 | tura
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | aras
# Processing Record 30 of Set 2 | fuchu
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | northam
# Processing Record 33 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 2 | mayumba
# Processing Record 35 of Set 2 | castro marim
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | nidda
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | kanakapura
# Processing Record 40 of Set 2 | bay roberts
# Processing Record 41 of Set 2 | ninh binh
# Processing Record 42 of Set 2 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 43 of Set 2 | la ronge
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | port-gentil
# Processing Record 46 of Set 2 | medicine hat
# Processing Record 47 of Set 2 | straumen
# Processing Record 48 of Set 2 | okhotsk
# Processing Record 49 of Set 2 | hovd
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | derby
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | payo
# Processing Record 4 of Set 3 | mangrol
# Processing Record 5 of Set 3 | cibeureum
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 8 of Set 3 | sao joao da barra
# Processing Record 9 of Set 3 | port hedland
# Processing Record 10 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 3 | sundumbili
# Processing Record 12 of Set 3 | keskin
# Processing Record 13 of Set 3 | bengkulu
# Processing Record 14 of Set 3 | nikolskoye
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | alta floresta
# Processing Record 17 of Set 3 | tolaga bay
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | iskateley
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | norman wells
# Processing Record 24 of Set 3 | laiyang
# Processing Record 25 of Set 3 | qui nhon
# Processing Record 26 of Set 3 | tromso
# Processing Record 27 of Set 3 | kabinda
# Processing Record 28 of Set 3 | bilma
# Processing Record 29 of Set 3 | daru
# Processing Record 30 of Set 3 | port alfred
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | imbituba
# Processing Record 33 of Set 3 | laguna
# Processing Record 34 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 3 | galesong
# Processing Record 36 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 37 of Set 3 | roswell
# Processing Record 38 of Set 3 | victoria
# Processing Record 39 of Set 3 | poum
# Processing Record 40 of Set 3 | coquimbo
# Processing Record 41 of Set 3 | mayo
# Processing Record 42 of Set 3 | sorland
# Processing Record 43 of Set 3 | machinga
# Processing Record 44 of Set 3 | menomonie
# Processing Record 45 of Set 3 | cidreira
# Processing Record 46 of Set 3 | lethem
# Processing Record 47 of Set 3 | channel-port aux basques
# Processing Record 48 of Set 3 | raton
# Processing Record 49 of Set 3 | makinsk
# Processing Record 50 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 4 | aykhal
# Processing Record 2 of Set 4 | ondangwa
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | gigmoto
# Processing Record 5 of Set 4 | nanortalik
# Processing Record 6 of Set 4 | tiquisate
# Processing Record 7 of Set 4 | xingyi
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | luanda
# Processing Record 11 of Set 4 | deputatskiy
# Processing Record 12 of Set 4 | killybegs
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | asfi
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | belmonte
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | bam
# Processing Record 19 of Set 4 | ust-koksa
# Processing Record 20 of Set 4 | yulara
# Processing Record 21 of Set 4 | ambilobe
# Processing Record 22 of Set 4 | hobart
# Processing Record 23 of Set 4 | alexandria
# Processing Record 24 of Set 4 | nara
# Processing Record 25 of Set 4 | koungou
# Processing Record 26 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 4 | prince albert
# Processing Record 28 of Set 4 | dandeli
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | hakodate
# Processing Record 31 of Set 4 | cabedelo
# Processing Record 32 of Set 4 | souillac
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | alvaraes
# Processing Record 35 of Set 4 | sartell
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | caieiras
# Processing Record 38 of Set 4 | namibe
# Processing Record 39 of Set 4 | sitka
# Processing Record 40 of Set 4 | tabukiniberu
# City not found. Skipping...
# Processing Record 41 of Set 4 | upernavik
# Processing Record 42 of Set 4 | washougal
# Processing Record 43 of Set 4 | potosi
# Processing Record 44 of Set 4 | kiama
# Processing Record 45 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 4 | saint-joseph
# Processing Record 47 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 4 | manaure
# Processing Record 49 of Set 4 | ixtapa
# Processing Record 50 of Set 4 | san pedro
# Processing Record 1 of Set 5 | el alto
# Processing Record 2 of Set 5 | orebro
# Processing Record 3 of Set 5 | adre
# Processing Record 4 of Set 5 | ancud
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | fornosovo
# Processing Record 7 of Set 5 | tir pol
# City not found. Skipping...
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | meulaboh
# Processing Record 10 of Set 5 | pahrump
# Processing Record 11 of Set 5 | altay
# Processing Record 12 of Set 5 | gunnedah
# Processing Record 13 of Set 5 | dalbandin
# Processing Record 14 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 5 | tuktoyaktuk
# Processing Record 17 of Set 5 | marabba
# Processing Record 18 of Set 5 | torrington
# Processing Record 19 of Set 5 | jamestown
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | palmer
# Processing Record 22 of Set 5 | key largo
# Processing Record 23 of Set 5 | sambava
# Processing Record 24 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 5 | rorvik
# Processing Record 26 of Set 5 | pacific grove
# Processing Record 27 of Set 5 | slave lake
# Processing Record 28 of Set 5 | singaraja
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | nome
# Processing Record 31 of Set 5 | mar del plata
# Processing Record 32 of Set 5 | ukiah
# Processing Record 33 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | anloga
# Processing Record 36 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 5 | necochea
# Processing Record 38 of Set 5 | lebu
# Processing Record 39 of Set 5 | tarko-sale
# Processing Record 40 of Set 5 | fare
# Processing Record 41 of Set 5 | te anau
# Processing Record 42 of Set 5 | pimentel
# Processing Record 43 of Set 5 | katsuura
# Processing Record 44 of Set 5 | ous
# Processing Record 45 of Set 5 | fria
# Processing Record 46 of Set 5 | bac lieu
# Processing Record 47 of Set 5 | inhambane
# Processing Record 48 of Set 5 | jurado
# Processing Record 49 of Set 5 | vila velha
# Processing Record 50 of Set 5 | chicama
# Processing Record 1 of Set 6 | mednogorsk
# Processing Record 2 of Set 6 | erdemli
# Processing Record 3 of Set 6 | kununurra
# Processing Record 4 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 6 | superior
# Processing Record 6 of Set 6 | yellowknife
# Processing Record 7 of Set 6 | la asuncion
# Processing Record 8 of Set 6 | ponta delgada
# Processing Record 9 of Set 6 | hauterive
# Processing Record 10 of Set 6 | mana
# Processing Record 11 of Set 6 | prince rupert
# Processing Record 12 of Set 6 | solano
# Processing Record 13 of Set 6 | ilulissat
# Processing Record 14 of Set 6 | myitkyina
# Processing Record 15 of Set 6 | sicamous
# Processing Record 16 of Set 6 | san jose
# Processing Record 17 of Set 6 | kharela
# Processing Record 18 of Set 6 | mporokoso
# Processing Record 19 of Set 6 | viedma
# Processing Record 20 of Set 6 | sao geraldo do araguaia
# Processing Record 21 of Set 6 | gizo
# Processing Record 22 of Set 6 | kaspiyskiy
# Processing Record 23 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 24 of Set 6 | constitucion
# Processing Record 25 of Set 6 | orange cove
# Processing Record 26 of Set 6 | bredasdorp
# Processing Record 27 of Set 6 | arawa
# Processing Record 28 of Set 6 | ereymentau
# Processing Record 29 of Set 6 | terrace
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | elizabeth city
# Processing Record 32 of Set 6 | kinango
# Processing Record 33 of Set 6 | dhone
# Processing Record 34 of Set 6 | fairbanks
# Processing Record 35 of Set 6 | boguchany
# Processing Record 36 of Set 6 | mount gambier
# Processing Record 37 of Set 6 | lakes entrance
# Processing Record 38 of Set 6 | yagodnoye
# Processing Record 39 of Set 6 | saint-anselme
# Processing Record 40 of Set 6 | ottawa
# Processing Record 41 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 6 | buala
# Processing Record 43 of Set 6 | evanston
# Processing Record 44 of Set 6 | maroantsetra
# Processing Record 45 of Set 6 | san isidro
# Processing Record 46 of Set 6 | tautira
# Processing Record 47 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 48 of Set 6 | henties bay
# Processing Record 49 of Set 6 | sakakah
# Processing Record 50 of Set 6 | ritchie
# Processing Record 1 of Set 7 | gat
# Processing Record 2 of Set 7 | prieska
# Processing Record 3 of Set 7 | provideniya
# Processing Record 4 of Set 7 | vanavara
# Processing Record 5 of Set 7 | kokuy
# Processing Record 6 of Set 7 | beloha
# Processing Record 7 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 7 | hami
# Processing Record 9 of Set 7 | opuwo
# Processing Record 10 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 11 of Set 7 | rawson
# Processing Record 12 of Set 7 | kaeo
# Processing Record 13 of Set 7 | kyaikto
# Processing Record 14 of Set 7 | vila franca do campo
# Processing Record 15 of Set 7 | bolivar
# Processing Record 16 of Set 7 | nemuro
# Processing Record 17 of Set 7 | golden
# Processing Record 18 of Set 7 | bolshaya sosnova
# Processing Record 19 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 7 | port hardy
# Processing Record 22 of Set 7 | phalodi
# Processing Record 23 of Set 7 | chumikan
# Processing Record 24 of Set 7 | gryazi
# Processing Record 25 of Set 7 | mantua
# Processing Record 26 of Set 7 | tezu
# Processing Record 27 of Set 7 | excelsior springs
# Processing Record 28 of Set 7 | lorengau
# Processing Record 29 of Set 7 | oxford
# Processing Record 30 of Set 7 | santa maria
# Processing Record 31 of Set 7 | inowroclaw
# Processing Record 32 of Set 7 | kidal
# Processing Record 33 of Set 7 | oranjestad
# Processing Record 34 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | cabinda
# Processing Record 36 of Set 7 | bogande
# Processing Record 37 of Set 7 | masuda
# Processing Record 38 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 7 | hvittingfoss
# Processing Record 40 of Set 7 | maldonado
# Processing Record 41 of Set 7 | corinto
# Processing Record 42 of Set 7 | zambezi
# Processing Record 43 of Set 7 | rosetown
# Processing Record 44 of Set 7 | villefranche-de-rouergue
# Processing Record 45 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | kaohsiung
# Processing Record 47 of Set 7 | vestmannaeyjar
# Processing Record 48 of Set 7 | airai
# Processing Record 49 of Set 7 | anadyr
# Processing Record 50 of Set 7 | bathsheba
# Processing Record 1 of Set 8 | luderitz
# Processing Record 2 of Set 8 | palmas
# Processing Record 3 of Set 8 | ust-kuyga
# Processing Record 4 of Set 8 | antagan
# City not found. Skipping...
# Processing Record 5 of Set 8 | goundam
# Processing Record 6 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 7 of Set 8 | lazaro cardenas
# Processing Record 8 of Set 8 | aloleng
# Processing Record 9 of Set 8 | kahului
# Processing Record 10 of Set 8 | brae
# Processing Record 11 of Set 8 | mount isa
# Processing Record 12 of Set 8 | qesarya
# Processing Record 13 of Set 8 | luena
# Processing Record 14 of Set 8 | portland
# Processing Record 15 of Set 8 | shenjiamen
# Processing Record 16 of Set 8 | baykit
# Processing Record 17 of Set 8 | charters towers
# Processing Record 18 of Set 8 | qasigiannguit
# Processing Record 19 of Set 8 | nhulunbuy
# Processing Record 20 of Set 8 | buraydah
# Processing Record 21 of Set 8 | aklavik
# Processing Record 22 of Set 8 | bonga
# Processing Record 23 of Set 8 | aswan
# Processing Record 24 of Set 8 | burgeo
# Processing Record 25 of Set 8 | salisbury
# Processing Record 26 of Set 8 | taoudenni
# Processing Record 27 of Set 8 | turinsk
# Processing Record 28 of Set 8 | marawi
# Processing Record 29 of Set 8 | fallon
# Processing Record 30 of Set 8 | ramhormoz
# Processing Record 31 of Set 8 | maues
# Processing Record 32 of Set 8 | lichinga
# Processing Record 33 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 8 | mango
# Processing Record 35 of Set 8 | vardo
# Processing Record 36 of Set 8 | saldanha
# Processing Record 37 of Set 8 | solone
# Processing Record 38 of Set 8 | sibu
# Processing Record 39 of Set 8 | ebolowa
# Processing Record 40 of Set 8 | asau
# Processing Record 41 of Set 8 | port augusta
# Processing Record 42 of Set 8 | targusor
# Processing Record 43 of Set 8 | ahipara
# Processing Record 44 of Set 8 | papara
# Processing Record 45 of Set 8 | baruun-urt
# Processing Record 46 of Set 8 | raymond
# Processing Record 47 of Set 8 | fandriana
# Processing Record 48 of Set 8 | kiruna
# Processing Record 49 of Set 8 | saskylakh
# Processing Record 50 of Set 8 | camana
# Processing Record 1 of Set 9 | srednekolymsk
# Processing Record 2 of Set 9 | saint-leu
# Processing Record 3 of Set 9 | iwanai
# Processing Record 4 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 5 of Set 9 | kajaani
# Processing Record 6 of Set 9 | baherden
# Processing Record 7 of Set 9 | lermontovka
# Processing Record 8 of Set 9 | ayagoz
# Processing Record 9 of Set 9 | porto novo
# Processing Record 10 of Set 9 | waddan
# Processing Record 11 of Set 9 | maun
# Processing Record 12 of Set 9 | topliceni
# Processing Record 13 of Set 9 | ballsh
# Processing Record 14 of Set 9 | moyobamba
# Processing Record 15 of Set 9 | comodoro rivadavia
# Processing Record 16 of Set 9 | bushehr
# Processing Record 17 of Set 9 | grand haven
# Processing Record 18 of Set 9 | santa fe
# Processing Record 19 of Set 9 | puerto narino
# Processing Record 20 of Set 9 | byron bay
# Processing Record 21 of Set 9 | ugoofaaru
# Processing Record 22 of Set 9 | muros
# Processing Record 23 of Set 9 | saint marys
# Processing Record 24 of Set 9 | mnogovershinnyy
# Processing Record 25 of Set 9 | pujili
# Processing Record 26 of Set 9 | salalah
# Processing Record 27 of Set 9 | lugovskiy
# City not found. Skipping...
# Processing Record 28 of Set 9 | port macquarie
# Processing Record 29 of Set 9 | adrar
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | goderich
# Processing Record 32 of Set 9 | staraya kulatka
# Processing Record 33 of Set 9 | la orilla
# Processing Record 34 of Set 9 | muli
# Processing Record 35 of Set 9 | xai-xai
# Processing Record 36 of Set 9 | seoul
# Processing Record 37 of Set 9 | kanniyakumari
# Processing Record 38 of Set 9 | lavrentiya
# Processing Record 39 of Set 9 | innisfail
# Processing Record 40 of Set 9 | pathein
# Processing Record 41 of Set 9 | vilhena
# Processing Record 42 of Set 9 | yumen
# Processing Record 43 of Set 9 | phek
# Processing Record 44 of Set 9 | pangnirtung
# Processing Record 45 of Set 9 | mackay
# Processing Record 46 of Set 9 | caravelas
# Processing Record 47 of Set 9 | surgut
# Processing Record 48 of Set 9 | calabozo
# Processing Record 49 of Set 9 | indramayu
# Processing Record 50 of Set 9 | stornoway
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | hailar
# Processing Record 3 of Set 10 | tarnogskiy gorodok
# Processing Record 4 of Set 10 | puerto suarez
# Processing Record 5 of Set 10 | shimoda
# Processing Record 6 of Set 10 | luba
# Processing Record 7 of Set 10 | kysyl-syr
# Processing Record 8 of Set 10 | leningradskiy
# Processing Record 9 of Set 10 | bassano
# Processing Record 10 of Set 10 | kijang
# Processing Record 11 of Set 10 | carutapera
# Processing Record 12 of Set 10 | tombouctou
# Processing Record 13 of Set 10 | khiri mat
# Processing Record 14 of Set 10 | dorado
# Processing Record 15 of Set 10 | santa isabel
# Processing Record 16 of Set 10 | rincon
# Processing Record 17 of Set 10 | manta
# Processing Record 18 of Set 10 | jaypur
# Processing Record 19 of Set 10 | melfort
# Processing Record 20 of Set 10 | mapiripan
# Processing Record 21 of Set 10 | hambantota
# Processing Record 22 of Set 10 | wangkui
# Processing Record 23 of Set 10 | devils lake
# Processing Record 24 of Set 10 | alofi
# Processing Record 25 of Set 10 | birao
# Processing Record 26 of Set 10 | am timan
# Processing Record 27 of Set 10 | saint michael
# Processing Record 28 of Set 10 | prachuap khiri khan
# Processing Record 29 of Set 10 | guerrero negro
# Processing Record 30 of Set 10 | lundazi
# Processing Record 31 of Set 10 | udachnyy
# Processing Record 32 of Set 10 | saint-paul
# Processing Record 33 of Set 10 | caninde
# Processing Record 34 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 10 | coihaique
# Processing Record 36 of Set 10 | centralia
# Processing Record 37 of Set 10 | san patricio
# Processing Record 38 of Set 10 | dong xoai
# Processing Record 39 of Set 10 | olafsvik
# Processing Record 40 of Set 10 | alice springs
# Processing Record 41 of Set 10 | yuzawa
# Processing Record 42 of Set 10 | solnechnyy
# Processing Record 43 of Set 10 | dwarka
# Processing Record 44 of Set 10 | caucaia
# Processing Record 45 of Set 10 | ballina
# Processing Record 46 of Set 10 | englehart
# Processing Record 47 of Set 10 | huitziltepec
# Processing Record 48 of Set 10 | nyandoma
# Processing Record 49 of Set 10 | kusk
# City not found. Skipping...
# Processing Record 50 of Set 10 | prainha
# Processing Record 1 of Set 11 | mezen
# Processing Record 2 of Set 11 | roma
# Processing Record 3 of Set 11 | gulf gate estates
# Processing Record 4 of Set 11 | kavaratti
# Processing Record 5 of Set 11 | esil
# Processing Record 6 of Set 11 | eureka
# Processing Record 7 of Set 11 | cruden bay
# City not found. Skipping...
# Processing Record 8 of Set 11 | kailua
# Processing Record 9 of Set 11 | sinnamary
# Processing Record 10 of Set 11 | port blair
# Processing Record 11 of Set 11 | yangambi
# Processing Record 12 of Set 11 | killarney
# Processing Record 13 of Set 11 | sao filipe
# Processing Record 14 of Set 11 | trincomalee
# Processing Record 15 of Set 11 | ligayan
# Processing Record 16 of Set 11 | machaneng
# Processing Record 17 of Set 11 | encantado
# Processing Record 18 of Set 11 | ostrovnoy
# Processing Record 19 of Set 11 | darab
# Processing Record 20 of Set 11 | krasnoselkup
# Processing Record 21 of Set 11 | kaitangata
# Processing Record 22 of Set 11 | ust-maya
# Processing Record 23 of Set 11 | imeni poliny osipenko
# Processing Record 24 of Set 11 | moen
# Processing Record 25 of Set 11 | beringovskiy
# Processing Record 26 of Set 11 | bosaso
# Processing Record 27 of Set 11 | witu
# Processing Record 28 of Set 11 | grindavik
# Processing Record 29 of Set 11 | los llanos de aridane
# Processing Record 30 of Set 11 | faya
# Processing Record 31 of Set 11 | hasaki
# Processing Record 32 of Set 11 | paamiut
# Processing Record 33 of Set 11 | majene
# Processing Record 34 of Set 11 | alhama de murcia
# Processing Record 35 of Set 11 | aksarka
# Processing Record 36 of Set 11 | ossora
# Processing Record 37 of Set 11 | peniche
# Processing Record 38 of Set 11 | hirara
# Processing Record 39 of Set 11 | langreo
# Processing Record 40 of Set 11 | ilave
# Processing Record 41 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 42 of Set 11 | ihosy
# Processing Record 43 of Set 11 | itapuranga
# Processing Record 44 of Set 11 | marsa matruh
# Processing Record 45 of Set 11 | puerto colombia
# Processing Record 46 of Set 11 | kamiiso
# Processing Record 47 of Set 11 | mitsamiouli
# Processing Record 48 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 49 of Set 11 | zanjan
# Processing Record 50 of Set 11 | turukhansk
# Processing Record 1 of Set 12 | yuanping
# Processing Record 2 of Set 12 | lagoa
# Processing Record 3 of Set 12 | tiarei
# Processing Record 4 of Set 12 | kabanjahe
# Processing Record 5 of Set 12 | mbandaka
# Processing Record 6 of Set 12 | geraldton
# Processing Record 7 of Set 12 | rakhya
# City not found. Skipping...
# Processing Record 8 of Set 12 | portadown
# Processing Record 9 of Set 12 | karasburg
# Processing Record 10 of Set 12 | almaznyy
# Processing Record 11 of Set 12 | tabou
# Processing Record 12 of Set 12 | codrington
# Processing Record 13 of Set 12 | halifax
# Processing Record 14 of Set 12 | biak
# Processing Record 15 of Set 12 | mayor pablo lagerenza
# Processing Record 16 of Set 12 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 17 of Set 12 | clarence town
# Processing Record 18 of Set 12 | praia
# Processing Record 19 of Set 12 | birsk
# Processing Record 20 of Set 12 | sokoni
# Processing Record 21 of Set 12 | mokhsogollokh
# Processing Record 22 of Set 12 | san quintin
# Processing Record 23 of Set 12 | sungaipenuh
# Processing Record 24 of Set 12 | taltal
# Processing Record 25 of Set 12 | taksimo
# Processing Record 26 of Set 12 | xinyu
# Processing Record 27 of Set 12 | krasnoyarskiy
# Processing Record 28 of Set 12 | yeppoon
# Processing Record 29 of Set 12 | vokhtoga
# Processing Record 30 of Set 12 | toyooka
# Processing Record 31 of Set 12 | belen
# Processing Record 32 of Set 12 | padang
# Processing Record 33 of Set 12 | high rock
# Processing Record 34 of Set 12 | moron
# Processing Record 35 of Set 12 | dicabisagan
# Processing Record 36 of Set 12 | dubrovka
# Processing Record 37 of Set 12 | haines junction
# Processing Record 38 of Set 12 | borovoy
# Processing Record 39 of Set 12 | denpasar
# Processing Record 40 of Set 12 | kaduy
# Processing Record 41 of Set 12 | abu dhabi
# Processing Record 42 of Set 12 | sembe
# Processing Record 43 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 12 | mazamari
# Processing Record 45 of Set 12 | alamosa
# Processing Record 46 of Set 12 | urziceni
# Processing Record 47 of Set 12 | sol-iletsk
# Processing Record 48 of Set 12 | sosnovo-ozerskoye
# Processing Record 49 of Set 12 | ratlam
# Processing Record 50 of Set 12 | svetlogorsk
# Processing Record 1 of Set 13 | acapulco
# Processing Record 2 of Set 13 | brasilia
# Processing Record 3 of Set 13 | lagos
# Processing Record 4 of Set 13 | naze
# Processing Record 5 of Set 13 | hastings
# Processing Record 6 of Set 13 | samut songkhram
# Processing Record 7 of Set 13 | la reforma
# Processing Record 8 of Set 13 | huehuetenango
# Processing Record 9 of Set 13 | naryan-mar
# Processing Record 10 of Set 13 | santiago de cao
# Processing Record 11 of Set 13 | ngunguru
# Processing Record 12 of Set 13 | onega
# Processing Record 13 of Set 13 | xuddur
# Processing Record 14 of Set 13 | mucurapo
# Processing Record 15 of Set 13 | rudnyy
# Processing Record 16 of Set 13 | brewster
# Processing Record 17 of Set 13 | pochutla
# Processing Record 18 of Set 13 | rebrikha
# Processing Record 19 of Set 13 | sulangan
# Processing Record 20 of Set 13 | takoradi
# Processing Record 21 of Set 13 | puerto rondon
# Processing Record 22 of Set 13 | birobidzhan
# Processing Record 23 of Set 13 | morondava
# Processing Record 24 of Set 13 | bereda
# Processing Record 25 of Set 13 | nuevo casas grandes
# Processing Record 26 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 27 of Set 13 | liku
# Processing Record 28 of Set 13 | ranfurly
# Processing Record 29 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 13 | west bay
# Processing Record 31 of Set 13 | santa cruz
# Processing Record 32 of Set 13 | benavente
# Processing Record 33 of Set 13 | kosa
# Processing Record 34 of Set 13 | sterling
# Processing Record 35 of Set 13 | beya
# Processing Record 36 of Set 13 | yarovoye
# Processing Record 37 of Set 13 | noumea
# Processing Record 38 of Set 13 | hay river
# Processing Record 39 of Set 13 | pasni
# Processing Record 40 of Set 13 | karratha
# Processing Record 41 of Set 13 | chenzhou
# Processing Record 42 of Set 13 | farias brito
# Processing Record 43 of Set 13 | takaka
# Processing Record 44 of Set 13 | ucluelet
# Processing Record 45 of Set 13 | sistranda
# Processing Record 46 of Set 13 | astorga
# Processing Record 47 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 13 | yaan
# Processing Record 49 of Set 13 | saint george
# Processing Record 50 of Set 13 | santiago
# Processing Record 1 of Set 14 | balabac
# Processing Record 2 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 14 | zhigansk
# Processing Record 4 of Set 14 | varnamo
# Processing Record 5 of Set 14 | severo-yeniseyskiy
# Processing Record 6 of Set 14 | katobu
# Processing Record 7 of Set 14 | soure
# Processing Record 8 of Set 14 | zhanakorgan
# Processing Record 9 of Set 14 | pilar
# Processing Record 10 of Set 14 | huejuquilla el alto
# Processing Record 11 of Set 14 | neyshabur
# Processing Record 12 of Set 14 | sola
# Processing Record 13 of Set 14 | maceio
# Processing Record 14 of Set 14 | honavar
# Processing Record 15 of Set 14 | nouakchott
# Processing Record 16 of Set 14 | krabi
# Processing Record 17 of Set 14 | parit buntar
# Processing Record 18 of Set 14 | nouadhibou
# Processing Record 19 of Set 14 | chemal
# Processing Record 20 of Set 14 | port moresby
# Processing Record 21 of Set 14 | palu
# Processing Record 22 of Set 14 | isangel
# Processing Record 23 of Set 14 | gamba
# Processing Record 24 of Set 14 | barguzin
# Processing Record 25 of Set 14 | umtata
# Processing Record 26 of Set 14 | khash
# Processing Record 27 of Set 14 | lahaina
# Processing Record 28 of Set 14 | narsaq
# Processing Record 29 of Set 14 | yanacancha
# Processing Record 30 of Set 14 | amot
# Processing Record 31 of Set 14 | sidney
# Processing Record 32 of Set 14 | mugur-aksy
# Processing Record 33 of Set 14 | carson city
# Processing Record 34 of Set 14 | jishou
# Processing Record 35 of Set 14 | nha trang
# Processing Record 36 of Set 14 | ndjole
# Processing Record 37 of Set 14 | araguatins
# City not found. Skipping...
# Processing Record 38 of Set 14 | henzada
# City not found. Skipping...
# Processing Record 39 of Set 14 | poanas
# Processing Record 40 of Set 14 | neiafu
# Processing Record 41 of Set 14 | nazare
# Processing Record 42 of Set 14 | paita
# Processing Record 43 of Set 14 | balsta
# Processing Record 44 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 45 of Set 14 | vondrozo
# Processing Record 46 of Set 14 | itoman
# Processing Record 47 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 48 of Set 14 | arinos
# Processing Record 49 of Set 14 | niamey
# Processing Record 50 of Set 14 | butka
# Processing Record 1 of Set 15 | maltahohe
# Processing Record 2 of Set 15 | kangaatsiaq
# Processing Record 3 of Set 15 | lincoln
# Processing Record 4 of Set 15 | chifeng
# Processing Record 5 of Set 15 | havre-saint-pierre
# Processing Record 6 of Set 15 | jalu
# Processing Record 7 of Set 15 | hualmay
# Processing Record 8 of Set 15 | cajnice
# Processing Record 9 of Set 15 | pemba
# Processing Record 10 of Set 15 | amga
# Processing Record 11 of Set 15 | markala
# Processing Record 12 of Set 15 | arman
# Processing Record 13 of Set 15 | madang
# Processing Record 14 of Set 15 | cap malheureux
# Processing Record 15 of Set 15 | ponnani
# Processing Record 16 of Set 15 | tete
# Processing Record 17 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 15 | trairi
# Processing Record 19 of Set 15 | diourbel
# Processing Record 20 of Set 15 | wajima
# Processing Record 21 of Set 15 | puerto escondido
# Processing Record 22 of Set 15 | varena
# Processing Record 23 of Set 15 | carballo
# Processing Record 24 of Set 15 | libenge
# Processing Record 25 of Set 15 | san carlos del zulia
# Processing Record 26 of Set 15 | guasdualito
# Processing Record 27 of Set 15 | kanker
# Processing Record 28 of Set 15 | progreso
# Processing Record 29 of Set 15 | labuhan
# Processing Record 30 of Set 15 | old road
# City not found. Skipping...
# Processing Record 31 of Set 15 | juneau
# Processing Record 32 of Set 15 | lasa
# Processing Record 33 of Set 15 | zhangye
# Processing Record 34 of Set 15 | verkhnevilyuysk
# Processing Record 35 of Set 15 | marjamaa
# Processing Record 36 of Set 15 | mandalgovi
# Processing Record 37 of Set 15 | cairns
# Processing Record 38 of Set 15 | lata
# Processing Record 39 of Set 15 | severobaykalsk
# Processing Record 40 of Set 15 | emerald
# Processing Record 41 of Set 15 | port lincoln
# Processing Record 42 of Set 15 | medea
# Processing Record 43 of Set 15 | kabale
# Processing Record 44 of Set 15 | sept-iles
# Processing Record 45 of Set 15 | romitan
# Processing Record 46 of Set 15 | skibbereen
# Processing Record 47 of Set 15 | coolum beach
# Processing Record 48 of Set 15 | moram
# Processing Record 49 of Set 15 | chacabuco
# Processing Record 50 of Set 15 | agrij
# Processing Record 1 of Set 16 | dolores
# Processing Record 2 of Set 16 | union
# Processing Record 3 of Set 16 | haifa
# Processing Record 4 of Set 16 | llata
# Processing Record 5 of Set 16 | umm kaddadah
# Processing Record 6 of Set 16 | gayny
# Processing Record 7 of Set 16 | lalganj
# Processing Record 8 of Set 16 | quelimane
# Processing Record 9 of Set 16 | rongcheng
# Processing Record 10 of Set 16 | hamilton
# Processing Record 11 of Set 16 | ingham
# Processing Record 12 of Set 16 | arica
# Processing Record 13 of Set 16 | acarau
# Processing Record 14 of Set 16 | ayna
# Processing Record 15 of Set 16 | vryburg
# Processing Record 16 of Set 16 | savannakhet
# Processing Record 17 of Set 16 | alvorada
# Processing Record 18 of Set 16 | uray
# Processing Record 19 of Set 16 | dong hoi
# Processing Record 20 of Set 16 | luau
# Processing Record 21 of Set 16 | pafos
# Processing Record 22 of Set 16 | carlyle
# Processing Record 23 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 16 | pangai
# Processing Record 25 of Set 16 | kizilskoye
# Processing Record 26 of Set 16 | khuzhir
# Processing Record 27 of Set 16 | floro
# Processing Record 28 of Set 16 | manokwari
# Processing Record 29 of Set 16 | madaoua
# Processing Record 30 of Set 16 | turayf
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Vaini      TO -21.2000 -175.2000     77.00        73          20
# 1    Albany      US  42.6001  -73.9662     63.00        40          99
# 2  Cherskiy      RU  68.7500  161.3000     24.66        97          92
# 3    Dikson      RU  73.5069   80.5464     15.84        97          61
# 4    Marang      MY   5.2056  103.2059     77.00       100          20
# 5   Mareeba      AU -17.0000  145.4333     71.60        78          47
# 6    Zvecka      RS  44.6389   20.1647     50.00        93          75
# 7   Rikitea      PF -23.1203 -134.9692     78.44        79          69
# 8      Chuy      UY -33.6971  -53.4616     53.17        72           6
# 9     Asino      RU  56.9979   86.1452     41.70        68          13
#
#    Wind Speed Current Description
# 0       17.27        [few clouds]
# 1        3.00   [overcast clouds]
# 2        3.33   [overcast clouds]
# 3       11.32     [broken clouds]
# 4        2.30        [few clouds]
# 5       10.36  [scattered clouds]
# 6       17.27     [moderate rain]
# 7       13.22     [broken clouds]
# 8        6.11         [clear sky]
# 9        7.61        [few clouds]

# %%
# Saving cleaned dataframe
file_path = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(file_path, index=False)
